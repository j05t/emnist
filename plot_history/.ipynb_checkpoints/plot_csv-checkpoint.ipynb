# %%
# %matplotlib inline

# %%
import pandas
import numpy as np

# %%
df02 = pandas.read_csv("training_history_emnist_dropout_0.2.csv")
df03 = pandas.read_csv("training_history_emnist_dropout_0.3.csv")

# %%
df02 = df02.set_index("Modell")
df03 = df03.set_index("Modell")

# %%
df02
# Out:
#                    32 Epochs  48 Epochs  64 Epochs  80 Epochs  96 Epochs  \
# Modell
# Modell 0            0.272501   0.295001   0.257498   0.234997   0.230002
# Modell 1            0.335002   0.272501   0.262499   0.277501   0.267500
# Modell 2            0.309998   0.302500   0.282502   0.247502   0.297499
# Modell 3            0.300002   0.277501   0.255001   0.232500   0.244999
# Modell 4            0.322503   0.282502   0.279999   0.255001   0.237501
# Modell 5            0.272501   0.277501   0.260001   0.230002   0.262499
# Modell 6            0.277501   0.319999   0.260001   0.277501   0.267500
# Modell 7            0.285000   0.302500   0.269997   0.257498   0.255001
# Modell 8            0.307500   0.279999   0.267500   0.244999   0.287497
# Modell 9            0.307500   0.287497   0.244999   0.269997   0.252497
# Ensemble            0.227499   0.199997   0.197500   0.195003   0.187498
# Best single Model   0.272501   0.272501   0.244999   0.230002   0.230002
#
# ...

# %%
df03
# Out:
#                    32 Epochs  48 Epochs  64 Epochs  80 Epochs  96 Epochs  \
# Modell
# Modell 0            0.470001   0.470001   0.419998   0.489998   0.440001
# Modell 1            0.480002   0.480002   0.540000   0.319999   0.349998
# Modell 2            0.569999   0.389999   0.480002   0.419998   0.419998
# Modell 3            0.599998   0.559998   0.340003   0.520003   0.529999
# Modell 4            0.660002   0.510001   0.389999   0.349998   0.440001
# Modell 5            0.550002   0.520003   0.580001   0.400001   0.430000
# Modell 6            0.430000   0.379997   0.419998   0.340003   0.379997
# Modell 7            0.529999   0.419998   0.360000   0.529999   0.300002
# Modell 8            0.400001   0.520003   0.520003   0.430000   0.449997
# Modell 9            0.379997   0.440001   0.449997   0.550002   0.610000
# Ensemble            0.349998   0.309998   0.290000   0.260001   0.260001
# Best single Model   0.379997   0.379997   0.340003   0.319999   0.300002
#
# ...

# %%
# set x label range, starting with 32
r = np.arange(32,288 + 16,16)
r
# Out:
# array([ 32,  48,  64,  80,  96, 112, 128, 144, 160, 176, 192, 208, 224,
#        240, 256, 272, 288])

# %%
import matplotlib.pyplot as plt

axes = plt.gca()

# plot ensemble accuracy over training history
en_acc = df02.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot model accuracies over training history
for i in range(10):
    acc = df02.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy)

plt.title("0.2 dropout model accuracy over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["Ensemble"], loc='upper left')
#plt.xlim(32,224)
plt.show()

# %%
import matplotlib.pyplot as plt

axes = plt.gca()

# plot ensemble accuracy over training history
en_acc = df03.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot model accuracies over training history
for i in range(10):
    acc = df02.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy)

plt.title("0.3 dropout model accuracy over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["Ensemble"], loc='upper left')
#plt.xlim(32,224)
plt.show()

# %%
import matplotlib.pyplot as plt

axes = plt.gca()

# plot dropout 0.2 ensemble accuracy over training history
en_acc = df02.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot dropout 0.3 ensemble accuracy over training history
en_acc = df03.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "rs-")

# plot dropout 0.2 model accuracies over training history
for i in range(10):
    acc = df02.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy, "b:")
    
# plot dropout 0.3 model accuracies over training history
for i in range(10):
    acc = df03.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy, "r:")

plt.title("Model accuracies over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["0.2 Dropout Ensemble", "0.3 Dropout Ensemble"], loc='upper left')
#plt.xlim(32,224)
plt.show()

# %%
import matplotlib.pyplot as plt

axes = plt.gca()

# plot dropout 0.2 ensemble accuracy over training history
en_acc = df02.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot dropout 0.3 ensemble accuracy over training history
en_acc = df03.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "rs-")

plt.title("Model accuracies over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["Ensemble 0.2 Dropout", "Ensemble 0.3 Dropout"], loc='upper left')
#plt.xlim(32,224)
plt.show()
