# %%
# %matplotlib inline

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
df02 = pandas.read_csv("training_history_emnist_dropout_0.2.csv")
df03 = pandas.read_csv("training_history_emnist_dropout_0.3.csv")
df04 = pandas.read_csv("training_history_emnist_dropout_0.4.csv")
df05 = pandas.read_csv("training_history_emnist_dropout_0.5.csv")
df06 = pandas.read_csv("training_history_emnist_manual_lr.csv")

# %%
df02 = df02.set_index("Modell")
df03 = df03.set_index("Modell")
df04 = df04.set_index("Modell")
df05 = df05.set_index("Modell")
df06 = df06.set_index("Modell")

# %%
df02
# Out:
#                    16 Epochen  32 Epochen  48 Epochen  64 Epochen  80 Epochen  \
# Modell
# Modell 0             0.344998    0.272501    0.295001    0.257498    0.234997
# Modell 1             0.397497    0.335002    0.272501    0.262499    0.277501
# Modell 2             0.309998    0.309998    0.302500    0.282502    0.247502
# Modell 3             0.482500    0.300002    0.277501    0.255001    0.232500
# Modell 4             0.342500    0.322503    0.282502    0.279999    0.255001
# Modell 5             0.367498    0.272501    0.277501    0.260001    0.230002
# Modell 6             0.422502    0.277501    0.319999    0.260001    0.277501
# Modell 7             0.349998    0.285000    0.302500    0.269997    0.257498
# Modell 8             0.392503    0.307500    0.279999    0.267500    0.244999
# Modell 9             0.367498    0.307500    0.287497    0.244999    0.269997
# Ensemble             0.265002    0.227499    0.199997    0.197500    0.195003
# Best single Model    0.309998    0.272501    0.272501    0.244999    0.230002
#
#                    96 Epochen  112 Epochen  128 Epochen  144 Epochen  \
# Modell
# Modell 0             0.230002     0.230002     0.252497     0.234997
# Modell 1             0.267500     0.225002     0.260001     0.230002
# Modell 2             0.297499     0.285000     0.265002     0.277501
# Modell 3             0.244999     0.255001     0.260001     0.242501
# Modell 4             0.237501     0.244999     0.232500     0.255001
# Modell 5             0.262499     0.262499     0.217497     0.230002
# Modell 6             0.267500     0.237501     0.255001     0.242501
# Modell 7             0.255001     0.267500     0.277501     0.255001
# Modell 8             0.287497     0.257498     0.199997     0.230002
# Modell 9             0.252497     0.277501     0.239998     0.242501
# Ensemble             0.187498     0.195003     0.187498     0.177503
# Best single Model    0.230002     0.225002     0.199997     0.230002
#
#                    160 Epochen  176 Epochen  192 Epochen  208 Epochen  \
# Modell
# Modell 0              0.239998     0.230002     0.262499     0.227499
# Modell 1              0.277501     0.212502     0.247502     0.262499
# Modell 2              0.247502     0.230002     0.260001     0.292498
# Modell 3              0.247502     0.215000     0.262499     0.232500
# Modell 4              0.239998     0.237501     0.265002     0.244999
# Modell 5              0.262499     0.222498     0.285000     0.255001
# Modell 6              0.234997     0.234997     0.255001     0.232500
# Modell 7              0.237501     0.257498     0.247502     0.267500
# Modell 8              0.257498     0.227499     0.250000     0.225002
# Modell 9              0.232500     0.247502     0.222498     0.262499
# Ensemble              0.172502     0.185001     0.187498     0.177503
# Best single Model     0.232500     0.212502     0.222498     0.225002
#
#                    224 Epochen  240 Epochen  256 Epochen  272 Epochen  \
# Modell
# Modell 0              0.255001     0.212502     0.247502     0.239998
# Modell 1              0.252497     0.242501     0.230002     0.239998
# Modell 2              0.227499     0.222498     0.232500     0.222498
# Modell 3              0.215000     0.232500     0.234997     0.217497
# Modell 4              0.230002     0.252497     0.247502     0.279999
# Modell 5              0.250000     0.222498     0.244999     0.209999
# Modell 6              0.217497     0.227499     0.217497     0.255001
# Modell 7              0.290000     0.285000     0.225002     0.244999
# Modell 8              0.242501     0.255001     0.212502     0.234997
# Modell 9              0.237501     0.222498     0.274998     0.232500
# Ensemble              0.190002     0.185001     0.167501     0.174999
# Best single Model     0.215000     0.212502     0.212502     0.209999
#
#                    288 Epochen
# Modell
# Modell 0              0.234997
# Modell 1              0.269997
# Modell 2              0.207502
# Modell 3              0.237501
# Modell 4              0.260001
# Modell 5              0.207502
# Modell 6              0.234997
# Modell 7              0.255001
# Modell 8              0.242501
# Modell 9              0.262499
# Ensemble              0.180000
# Best single Model     0.207502

# %%
df03
# Out:
#                    16 Epochen  32 Epochen  48 Epochen  64 Epochen  80 Epochen  \
# Modell
# Modell 0                  NaN    0.470001    0.470001    0.419998    0.489998
# Modell 1                  NaN    0.480002    0.480002    0.540000    0.319999
# Modell 2                  NaN    0.569999    0.389999    0.480002    0.419998
# Modell 3                  NaN    0.599998    0.559998    0.340003    0.520003
# Modell 4                  NaN    0.660002    0.510001    0.389999    0.349998
# Modell 5                  NaN    0.550002    0.520003    0.580001    0.400001
# Modell 6                  NaN    0.430000    0.379997    0.419998    0.340003
# Modell 7                  NaN    0.529999    0.419998    0.360000    0.529999
# Modell 8                  NaN    0.400001    0.520003    0.520003    0.430000
# Modell 9                  NaN    0.379997    0.440001    0.449997    0.550002
# Ensemble                  NaN    0.349998    0.309998    0.290000    0.260001
# Best single Model         NaN    0.379997    0.379997    0.340003    0.319999
#
#                    96 Epochen  112 Epochen  128 Epochen  144 Epochen  \
# Modell
# Modell 0             0.440001     0.389999     0.489998     0.274998
# Modell 1             0.349998     0.540000     0.389999     0.282502
# Modell 2             0.419998     0.400001     0.480002     0.274998
# Modell 3             0.529999     0.389999     0.419998     0.309998
# Modell 4             0.440001     0.540000     0.419998     0.292498
# Modell 5             0.430000     0.480002     0.330001     0.274998
# Modell 6             0.379997     0.480002     0.319999     0.244999
# Modell 7             0.300002     0.500000     0.440001     0.255001
# Modell 8             0.449997     0.419998     0.379997     0.295001
# Modell 9             0.610000     0.400001     0.370002     0.267500
# Ensemble             0.260001     0.260001     0.250000     0.199997
# Best single Model    0.300002     0.389999     0.319999     0.244999
#
#                    160 Epochen  176 Epochen  192 Epochen  208 Epochen  \
# Modell
# Modell 0              0.220001     0.239998     0.244999     0.239998
# Modell 1              0.265002     0.250000     0.250000     0.274998
# Modell 2              0.265002     0.239998     0.269997     0.250000
# Modell 3              0.247502     0.269997     0.239998     0.237501
# Modell 4              0.262499     0.262499     0.257498     0.217497
# Modell 5              0.257498     0.269997     0.247502     0.290000
# Modell 6              0.295001     0.269997     0.227499     0.232500
# Modell 7              0.227499     0.227499     0.225002     0.262499
# Modell 8              0.242501     0.252497     0.230002     0.272501
# Modell 9              0.295001     0.285000     0.232500     0.252497
# Ensemble              0.187498     0.187498     0.174999     0.177503
# Best single Model     0.220001     0.227499     0.225002     0.217497
#
#                    224 Epochen  240 Epochen  256 Epochen  272 Epochen  \
# Modell
# Modell 0              0.252497     0.234997     0.239998     0.222498
# Modell 1              0.234997     0.222498     0.274998     0.269997
# Modell 2              0.244999     0.232500     0.262499     0.250000
# Modell 3              0.244999     0.250000     0.232500     0.222498
# Modell 4              0.244999     0.250000     0.239998     0.242501
# Modell 5              0.237501     0.292498     0.262499     0.269997
# Modell 6              0.257498     0.234997     0.212502     0.215000
# Modell 7              0.227499     0.257498     0.257498     0.225002
# Modell 8              0.277501     0.244999     0.215000     0.212502
# Modell 9              0.247502     0.209999     0.242501     0.250000
# Ensemble              0.187498     0.169998     0.190002     0.177503
# Best single Model     0.227499     0.209999     0.212502     0.212502
#
#                    288 Epochen
# Modell
# Modell 0              0.232500
# Modell 1              0.257498
# Modell 2              0.230002
# Modell 3              0.252497
# Modell 4              0.230002
# Modell 5              0.257498
# Modell 6              0.234997
# Modell 7              0.230002
# Modell 8              0.212502
# Modell 9              0.282502
# Ensemble              0.192499
# Best single Model     0.212502

# %%
df04
# Out:
#                    16 Epochen  32 Epochen  48 Epochen  64 Epochen  80 Epochen  \
# Modell
# Modell 0             0.317502    0.337499    0.287497    0.269997    0.237501
# Modell 1             0.445002    0.325000    0.279999    0.274998    0.250000
# Modell 2             0.370002    0.307500    0.260001    0.244999    0.257498
# Modell 3             0.354999    0.330001    0.277501    0.252497    0.274998
# Modell 4             0.372499    0.322503    0.277501    0.290000    0.227499
# Modell 5             0.392503    0.335002    0.330001    0.285000    0.279999
# Modell 6             0.342500    0.319999    0.300002    0.265002    0.297499
# Modell 7             0.360000    0.327498    0.300002    0.279999    0.262499
# Modell 8             0.377500    0.314999    0.257498    0.267500    0.260001
# Modell 9             0.360000    0.309998    0.265002    0.277501    0.297499
# Ensemble             0.252497    0.212502    0.204998    0.209999    0.197500
# Best single Model    0.317502    0.307500    0.257498    0.244999    0.227499
#
#                    96 Epochen  112 Epochen  128 Epochen  144 Epochen  \
# Modell
# Modell 0             0.250000     0.262499     0.232500     0.232500
# Modell 1             0.252497     0.244999     0.257498     0.287497
# Modell 2             0.267500     0.257498     0.267500     0.279999
# Modell 3             0.285000     0.217497     0.232500     0.242501
# Modell 4             0.247502     0.265002     0.232500     0.237501
# Modell 5             0.232500     0.272501     0.292498     0.255001
# Modell 6             0.237501     0.252497     0.250000     0.247502
# Modell 7             0.239998     0.250000     0.257498     0.242501
# Modell 8             0.257498     0.262499     0.237501     0.290000
# Modell 9             0.265002     0.274998     0.269997     0.247502
# Ensemble             0.192499     0.199997     0.190002     0.177503
# Best single Model    0.232500     0.217497     0.232500     0.232500
#
#                    160 Epochen  176 Epochen  192 Epochen  208 Epochen  \
# Modell
# Modell 0              0.212502     0.230002     0.257498     0.262499
# Modell 1              0.234997     0.239998     0.244999     0.247502
# Modell 2              0.277501     0.242501     0.237501     0.244999
# Modell 3              0.234997     0.242501     0.269997     0.255001
# Modell 4              0.220001     0.250000     0.227499     0.244999
# Modell 5              0.244999     0.230002     0.239998     0.257498
# Modell 6              0.215000     0.255001     0.255001     0.234997
# Modell 7              0.225002     0.247502     0.252497     0.239998
# Modell 8              0.242501     0.265002     0.239998     0.230002
# Modell 9              0.262499     0.239998     0.230002     0.239998
# Ensemble              0.182498     0.204998     0.182498     0.185001
# Best single Model     0.212502     0.230002     0.227499     0.230002
#
#                    224 Epochen  240 Epochen  256 Epochen  272 Epochen  \
# Modell
# Modell 0              0.267500     0.212502     0.244999     0.252497
# Modell 1              0.267500     0.239998     0.239998     0.267500
# Modell 2              0.234997     0.269997     0.237501     0.230002
# Modell 3              0.232500     0.242501     0.244999     0.222498
# Modell 4              0.225002     0.250000     0.222498     0.282502
# Modell 5              0.212502     0.234997     0.234997     0.209999
# Modell 6              0.237501     0.274998     0.237501     0.252497
# Modell 7              0.252497     0.222498     0.234997     0.215000
# Modell 8              0.267500     0.255001     0.225002     0.220001
# Modell 9              0.247502     0.237501     0.260001     0.242501
# Ensemble              0.180000     0.180000     0.172502     0.172502
# Best single Model     0.212502     0.212502     0.222498     0.209999
#
#                    288 Epochen
# Modell
# Modell 0              0.255001
# Modell 1              0.212502
# Modell 2              0.232500
# Modell 3              0.230002
# Modell 4              0.232500
# Modell 5              0.257498
# Modell 6              0.237501
# Modell 7              0.300002
# Modell 8              0.225002
# Modell 9              0.234997
# Ensemble              0.167501
# Best single Model     0.212502

# %%
df05
# Out:
#                    16 Epochen  32 Epochen  48 Epochen  64 Epochen  80 Epochen  \
# Modell
# Modell 0             0.467497    0.272501    0.290000    0.279999    0.230002
# Modell 1             0.384998    0.285000    0.269997    0.295001    0.250000
# Modell 2             0.357503    0.354999    0.305003    0.307500    0.287497
# Modell 3             0.335002    0.354999    0.247502    0.360000    0.274998
# Modell 4             0.332499    0.279999    0.277501    0.307500    0.250000
# Modell 5             0.382501    0.414997    0.252497    0.239998    0.287497
# Modell 6             0.317502    0.302500    0.257498    0.295001    0.272501
# Modell 7             0.410002    0.344998    0.302500    0.277501    0.247502
# Modell 8             0.372499    0.282502    0.342500    0.279999    0.252497
# Modell 9             0.352502    0.285000    0.314999    0.269997    0.265002
# Ensemble             0.262499    0.242501    0.217497    0.212502    0.212502
# Best single Model    0.317502    0.272501    0.247502    0.239998    0.230002
#
#                    96 Epochen  112 Epochen  128 Epochen  144 Epochen  \
# Modell
# Modell 0             0.255001     0.234997     0.269997     0.272501
# Modell 1             0.265002     0.262499     0.255001     0.255001
# Modell 2             0.225002     0.260001     0.282502     0.274998
# Modell 3             0.312501     0.262499     0.237501     0.257498
# Modell 4             0.239998     0.292498     0.232500     0.209999
# Modell 5             0.279999     0.319999     0.252497     0.244999
# Modell 6             0.247502     0.269997     0.312501     0.242501
# Modell 7             0.282502     0.247502     0.230002     0.274998
# Modell 8             0.255001     0.239998     0.309998     0.302500
# Modell 9             0.244999     0.242501     0.272501     0.265002
# Ensemble             0.197500     0.199997     0.207502     0.192499
# Best single Model    0.225002     0.234997     0.230002     0.209999
#
#                    160 Epochen  176 Epochen  192 Epochen  208 Epochen  \
# Modell
# Modell 0              0.234997     0.215000     0.217497     0.239998
# Modell 1              0.227499     0.212502     0.279999     0.262499
# Modell 2              0.230002     0.222498     0.247502     0.225002
# Modell 3              0.274998     0.239998     0.244999     0.260001
# Modell 4              0.234997     0.272501     0.227499     0.199997
# Modell 5              0.257498     0.252497     0.217497     0.244999
# Modell 6              0.255001     0.250000     0.227499     0.267500
# Modell 7              0.287497     0.237501     0.265002     0.234997
# Modell 8              0.230002     0.247502     0.265002     0.204998
# Modell 9              0.267500     0.242501     0.267500     0.215000
# Ensemble              0.202501     0.190002     0.185001     0.182498
# Best single Model     0.227499     0.212502     0.217497     0.199997
#
#                    224 Epochen  240 Epochen  256 Epochen  272 Epochen  \
# Modell
# Modell 0              0.217497     0.242501     0.257498     0.225002
# Modell 1              0.227499     0.282502     0.239998     0.237501
# Modell 2              0.244999     0.212502     0.239998     0.232500
# Modell 3              0.237501     0.252497     0.225002     0.209999
# Modell 4              0.217497     0.232500     0.237501     0.239998
# Modell 5              0.257498     0.225002     0.237501     0.257498
# Modell 6              0.232500     0.217497     0.260001     0.244999
# Modell 7              0.300002     0.252497     0.225002     0.255001
# Modell 8              0.225002     0.232500     0.244999     0.250000
# Modell 9              0.247502     0.274998     0.247502     0.230002
# Ensemble              0.185001     0.182498     0.190002     0.190002
# Best single Model     0.217497     0.212502     0.225002     0.209999
#
#                    288 Epochen
# Modell
# Modell 0              0.247502
# Modell 1              0.297499
# Modell 2              0.257498
# Modell 3              0.255001
# Modell 4              0.220001
# Modell 5              0.234997
# Modell 6              0.239998
# Modell 7              0.242501
# Modell 8              0.250000
# Modell 9              0.230002
# Ensemble              0.195003
# Best single Model     0.220001

# %%
df06
# Out:
#                    256 Epochen  257 Epochen  258 Epochen  259 Epochen  \
# Modell
# Modell 0              0.344998     0.222498     0.215000     0.209999
# Modell 1              0.397497     0.220001     0.225002     0.227499
# Modell 2              0.309998     0.204998     0.212502     0.207502
# Modell 3              0.482500     0.197500     0.187498     0.202501
# Modell 4              0.342500     0.230002     0.217497     0.217497
# Modell 5              0.367498     0.199997     0.195003     0.202501
# Modell 6              0.422502     0.217497     0.212502     0.207502
# Modell 7              0.349998     0.195003     0.174999     0.180000
# Modell 8              0.392503     0.197500     0.197500     0.195003
# Modell 9              0.367498     0.204998     0.215000     0.199997
# Ensemble              0.265002     0.177503     0.174999     0.172502
# Best single Model     0.309998     0.195003     0.174999     0.180000
#
#                    260 Epochen  261 Epochen  262 Epochen  263 Epochen  \
# Modell
# Modell 0              0.217497     0.217497     0.202501     0.212502
# Modell 1              0.217497     0.220001     0.202501     0.209999
# Modell 2              0.197500     0.197500     0.220001     0.195003
# Modell 3              0.204998     0.197500     0.215000     0.207502
# Modell 4              0.230002     0.227499     0.225002     0.220001
# Modell 5              0.207502     0.215000     0.199997     0.197500
# Modell 6              0.204998     0.212502     0.204998     0.199997
# Modell 7              0.185001     0.185001     0.185001     0.182498
# Modell 8              0.212502     0.185001     0.177503     0.190002
# Modell 9              0.202501     0.192499     0.204998     0.204998
# Ensemble              0.174999     0.167501     0.164998     0.162500
# Best single Model     0.185001     0.185001     0.177503     0.182498
#
#                    264 Epochen  265 Epochen  266 Epochen  267 Epochen  \
# Modell
# Modell 0              0.217497     0.209999     0.199997     0.204998
# Modell 1              0.227499     0.212502     0.212502     0.212502
# Modell 2              0.199997     0.197500     0.199997     0.199997
# Modell 3              0.209999     0.204998     0.207502     0.197500
# Modell 4              0.212502     0.212502     0.227499     0.209999
# Modell 5              0.204998     0.209999     0.220001     0.204998
# Modell 6              0.212502     0.199997     0.207502     0.217497
# Modell 7              0.182498     0.192499     0.185001     0.199997
# Modell 8              0.199997     0.185001     0.195003     0.185001
# Modell 9              0.197500     0.207502     0.215000     0.207502
# Ensemble              0.169998     0.169998     0.162500     0.160003
# Best single Model     0.182498     0.185001     0.185001     0.185001
#
#                    268 Epochen  269 Epochen  270 Epochen  271 Epochen  \
# Modell
# Modell 0              0.212502     0.212502     0.204998     0.212502
# Modell 1              0.204998     0.204998     0.212502     0.207502
# Modell 2              0.204998     0.209999     0.204998     0.207502
# Modell 3              0.217497     0.202501     0.202501     0.220001
# Modell 4              0.212502     0.204998     0.212502     0.220001
# Modell 5              0.217497     0.207502     0.212502     0.215000
# Modell 6              0.217497     0.209999     0.204998     0.204998
# Modell 7              0.195003     0.199997     0.197500     0.195003
# Modell 8              0.199997     0.182498     0.195003     0.187498
# Modell 9              0.204998     0.197500     0.204998     0.217497
# Ensemble              0.164998     0.160003     0.167501     0.160003
# Best single Model     0.195003     0.182498     0.195003     0.187498
#
#                    272 Epochen
# Modell
# Modell 0              0.239998
# Modell 1              0.239998
# Modell 2              0.222498
# Modell 3              0.217497
# Modell 4              0.279999
# Modell 5              0.209999
# Modell 6              0.255001
# Modell 7              0.244999
# Modell 8              0.234997
# Modell 9              0.232500
# Ensemble              0.174999
# Best single Model     0.209999

# %%
# set x label range, starting with 16
r = np.arange(16,288 + 16,16)
r
# Out:
# array([ 16,  32,  48,  64,  80,  96, 112, 128, 144, 160, 176, 192, 208,
#        224, 240, 256, 272, 288])

# %%
axes = plt.gca()

# plot ensemble accuracy over training history
en_acc = df02.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot model accuracies over training history
for i in range(10):
    acc = df02.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy)

plt.title("0.2 dropout model accuracy over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["Ensemble"], loc='upper right')
#plt.xlim(32,224)
plt.ylim(0.16, 0.5)
plt.show()

# %%
axes = plt.gca()

# plot ensemble accuracy over training history
en_acc = df03.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot model accuracies over training history
for i in range(10):
    acc = df03.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy)

plt.title("0.3 dropout model accuracy over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["Ensemble"], loc='upper right')
#plt.xlim(32,224)
plt.ylim(0.16, 0.5)
plt.show()

# %%
axes = plt.gca()

# plot ensemble accuracy over training history
en_acc = df04.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot model accuracies over training history
for i in range(10):
    acc = df04.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy)

plt.title("0.4 dropout model accuracy over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["Ensemble"], loc='upper right')
#plt.xlim(32,224)
plt.ylim(0.16, 0.5)
plt.show()

# %%
axes = plt.gca()

# plot ensemble accuracy over training history
en_acc = df05.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot model accuracies over training history
for i in range(10):
    acc = df05.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy)

plt.title("0.5 dropout model accuracy over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["Ensemble"], loc='upper right')
#plt.xlim(32,224)
plt.ylim(0.16, 0.5)
plt.show()

# %%
# Learning rate was set manually to 0.00001

# set x label range, starting with 256
r = np.arange(256,273)

axes = plt.gca()

# plot ensemble accuracy over training history
en_acc = df06.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot model accuracies over training history
for i in range(10):
    acc = df06.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy)

plt.title("0.2 dropout model accuracy, learning rate 1e-5")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["Ensemble"], loc='upper right')
#plt.xlim(32,224)
plt.ylim(0.159, 0.28)
plt.show()

# %%
# reset x label range, starting with 16
r = np.arange(16,288 + 16,16)
r
# Out:
# array([ 16,  32,  48,  64,  80,  96, 112, 128, 144, 160, 176, 192, 208,
#        224, 240, 256, 272, 288])

# %%
axes = plt.gca()

# plot dropout 0.2 ensemble accuracy over training history
en_acc = df02.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "rs-")

# plot dropout 0.3 ensemble accuracy over training history
en_acc = df03.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "gs-")

# plot dropout 0.4 ensemble accuracy over training history
en_acc = df04.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot dropout 0.5 ensemble accuracy over training history
en_acc = df05.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "ys-")

# plot dropout 0.2 model accuracies over training history
for i in range(10):
    acc = df02.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy, "r:")
    
# plot dropout 0.3 model accuracies over training history
for i in range(10):
    acc = df03.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy, "g:")
    
# plot dropout 0.4 model accuracies over training history
for i in range(10):
    acc = df04.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy, "b:")

# plot dropout 0.5 model accuracies over training history
for i in range(10):
    acc = df05.loc["Modell {}".format(i),:]
    accuracy = acc.values.tolist()
    plt.plot(r, accuracy, "y:")

plt.title("Model accuracies over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["0.2 Dropout Ensemble", "0.3 Dropout Ensemble", "0.4 Dropout Ensemble", "0.5 Dropout Ensemble"], loc='upper right')
#plt.xlim(32,224)
plt.ylim(0.16,0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

axes = plt.gca()

# plot dropout 0.2 ensemble accuracy over training history
en_acc = df02.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "rs-")

# plot dropout 0.3 ensemble accuracy over training history
en_acc = df03.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "gs-")

# plot dropout 0.4 ensemble accuracy over training history
en_acc = df04.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "bs-")

# plot dropout 0.5 ensemble accuracy over training history
en_acc = df05.loc["Ensemble",:]
ensemble_accuracy = en_acc.values.tolist()
plt.plot(r, ensemble_accuracy, "ys-")

plt.title("Model accuracies over training history")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["0.2 Dropout Ensemble", "0.3 Dropout Ensemble", "0.4 Dropout Ensemble", "0.5 Dropout Ensemble"], loc='upper right')
#plt.xlim(32,224)
#plt.ylim(0.16, 0.35)
plt.show()
